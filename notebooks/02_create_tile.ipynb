# %% [markdown]
# # Técnicas de *Tiling* para el Procesamiento de Imágenes SAR en el Contexto de Aprendizaje Automático
#
#
# Este codigo combina las complejas imagenes VH,VV en imagenes *tiles* con el proposito de entrenar y testear un algoritmo de detección y clasificacion.
#
# ## Introducción
#
# El procesamiento avanzado de imágenes de radar de apertura sintética (SAR), especialmente en aplicaciones de aprendizaje automático, requiere técnicas eficientes para manejar grandes volúmenes de datos. El tiling o segmentación en mosaicos, es crucial para la gestión de imágenes grandes, facilitando el procesamiento paralelo y reduciendo la carga computacional.
#
# ## Metodología
#
# El código analizado combina imágenes complejas SLC en polarizaciones VH y VV para formar imágenes en tiles, destinadas al entrenamiento de algoritmos de detección y clasificación. Se describen los pasos desde la lectura de las imágenes hasta su segmentación en mosaicos, destacando la importancia del cálculo de magnitud y fase para cada imagen procesada.
#
# ### Preparación y Ajuste de Imágenes
#
# Se utiliza *rasterio* para ajustar dimensiones de las imágenes mediante padding, asegurando que cada imagen sea divisible exactamente en tiles de dimensiones especificadas, considerando la superposición entre ellos.
#
# ### Cálculo de Magnitud y Fase
#
# Se calculan la magnitud y fase de las imágenes VH y VV, almacenando los resultados en un array de NumPy con cuatro canales, lo cual es esencial para las subsiguientes etapas de clasificación y detección.
#
# ### Segmentación en *Tiling*
#
# Este proceso implica combinar las imágenes ajustadas en un array de cuatro canales y segmentar este array en tiles cuadrados, que se almacenan individualmente, facilitando su uso en entrenamientos de modelos de aprendizaje profundo.
#
# ## Estructura de Archivos Generada
#
# Posteriormente, se crea una estructura de archivos donde cada tile contiene un array de NumPy con los cuatro canales calculados, adecuado para el entrenamiento de modelos:
#
#
# ```bash
#
#
# [TilePath]/[scene_id]/swath1/0_0.npy    | This is the chip data (complex numpy array),
#                                         | the filename is tx_ty.npy, where tx is the tile index in x axis,
#                                         | and ty is the tile index in y axis
#                                         | Each .npy has 4 channels, vh_mag, vh_phase, vv_mag, vv_phase
#
# [TilePath]/img_file_info.csv            | This file saved the file info of the scenes used
# ```

# %%
import numpy as np
from pathlib import Path
import numpy as np
import rasterio
import matplotlib.pyplot as plt

# Make Matplotlib plots appear inline
# %matplotlib inline

# %% [markdown]
# ## <combineVHVV:>
#
# ### Lectura y Ajuste de Imágenes:
#
# ```python
# with rasterio.open(vhFN) as src:
#     vhImg = src.read(1)  # Lee la primera banda
# ```
#
#
# Las imágenes SAR se leen utilizando la librería rasterio, que facilita el manejo de archivos GeoTIFF. Este paso inicial implica la lectura del primer canal de la imagen, generalmente representando una polarización específica del radar. Posteriormente, la imagen se ajusta en tamaño mediante un proceso de padding. Esto consiste en agregar filas y columnas de ceros a la imagen original para asegurar que las dimensiones de la imagen sean múltiplos del tamaño de los tiles, menos el solapamiento entre ellos.
#
# ### Cálculo de Magnitud y Fase:
#
# ```python
# padImg = np.pad(vhImg, pad_width=((0, padH), (0, padW)), mode="constant", constant_values=0)
# vhAbs = np.abs(padImg)
# vhPhase = np.angle(padImg)
# ```
#
# Para cada píxel de las imágenes VH y VV, se calcula la magnitud y la fase del número complejo correspondiente. Este paso es esencial porque las magnitudes y fases son características clave que se utilizan en la detección y clasificación en muchas aplicaciones de procesamiento de imágenes SAR. La función np.pad se utiliza para ajustar las dimensiones de la imagen, y las funciones np.abs y np.angle son utilizadas para calcular la magnitud y la fase, respectivamente.
#
#
# ### Combinación de Canales y Creación de Tiles:
#
# out = np.stack([vhAbs, vhPhase, vvAbs, vvPhase], axis=0)
#
# Los valores calculados de magnitud y fase para cada polarización se combinan en un único arreglo de cuatro canales. Este arreglo multidimensional se crea apilando los canales de magnitud y fase de las imágenes VH y VV. Posteriormente, este arreglo se segmenta en tiles, que son pequeños segmentos de la imagen de dimensiones predefinidas. Estos tiles se almacenan individualmente, lo que facilita su posterior procesamiento o uso en entrenamiento de modelos.

# %%
def combineVHVV(vhFN: Path, vvFN: Path, tileSize: int, tileOverlap: int) -> np.ndarray:
    """Combine VH and VV images to produce a 4-channel numpy array with absolute and phase values.
    
    Args:
    vhFN (Path): Path to the VH GeoTIFF file.
    vvFN (Path): Path to the VV GeoTIFF file.
    tileSize (int): Size of the tile for processing.
    tileOverlap (int): Overlap size of the tiles.
    
    Returns:
    np.ndarray: 4-channel numpy array containing the absolute and phase of VH and VV.
    """
    # Read VH image using rasterio
    with rasterio.open(vhFN) as src:
        vhImg = src.read(1)  # Read the first band

    imgH, imgW = vhImg.shape
    s = tileSize - tileOverlap
    newH = int(np.ceil((imgH - tileOverlap) / s) * s) + tileOverlap
    newW = int(np.ceil((imgW - tileOverlap) / s) * s) + tileOverlap
    padH = newH - imgH
    padW = newW - imgW

    # Padding the image
    padImg = np.pad(vhImg, pad_width=((0, padH), (0, padW)), mode="constant", constant_values=0)
    vhAbs = np.abs(padImg)
    vhPhase = np.angle(padImg)

    # Read VV image using rasterio
    with rasterio.open(vvFN) as src:
        vvImg = src.read(1)  # Read the first band

    padImg = np.pad(vvImg, pad_width=((0, padH), (0, padW)), mode="constant", constant_values=0)
    vvAbs = np.abs(padImg)
    vvPhase = np.angle(padImg)

    # Combine into a 4-channel array
    out = np.stack([vhAbs, vhPhase, vvAbs, vvPhase], axis=0)
    return out

# %% [markdown]
# ## <chopAndSaveTiles:>
#
#
# ```python
# for tx in range(numTileX):
#     for ty in range(numTileY):
#         x1 = tx * s
#         y1 = ty * s
#         x2 = x1 + tileSize
#         y2 = y1 + tileSize
#         FN = Path(outDir, f"{tx}_{ty}.npy")
#         with open(str(FN), "wb") as f:
#             np.save(f, combined[:, y1:y2, x1:x2])
# ```
#
# Este fragmento de código se encarga de dividir el arreglo combinado en tiles y guardar cada tile como un archivo .npy en el directorio especificado. Se calculan las coordenadas de cada tile basándose en el tamaño del tile y el solapamiento, y cada tile se guarda de manera que pueda ser accesible para procesos de aprendizaje automático posteriores.

# %%
def chopAndSaveTiles(
        combined: np.ndarray, outDir: Path , tileSize: int, tileOverlap: int
    ):
    """Chop the combined image (4 x H x W) into tiles
    """
    s = tileSize - tileOverlap
    imgH = combined.shape[1]
    imgW = combined.shape[2]
    numTileX = int( imgW / s )
    numTileY = int( imgH / s )
    if not outDir.exists():
        outDir.mkdir(parents = True, exist_ok = True)

    for tx in range( numTileX ):
        for ty in range( numTileY ):
            x1 = tx * s
            y1 = ty * s
            x2 = x1 + tileSize
            y2 = y1 + tileSize
            FN = Path(outDir, f"{tx}_{ty}.npy")
            with open(str(FN), "wb") as f:
                np.save( f, combined[ :, y1:y2, x1:x2 ] )

# %%
foldDf = pd.read_csv("fold.csv")

sceneList = foldDf['scene_id'].values
swathList = [1, 2, 3]

data_path =  "../../data/"

xView3_SLC_GRD_correspondences = pd.read_csv("../../data/SARFish" + "/labels/xView3_SLC_GRD_correspondences.csv")

xView3_SLC_GRD_correspondences = xView3_SLC_GRD_correspondences[
    xView3_SLC_GRD_correspondences["scene_id"].isin(sceneList)
]

SARFish_root_directory = Path(data_path)

product_type = "SLC"

tileSize = 1024

tileOverlap = 64


tilePath = Path("extracted_slc_chip/")

if not tilePath.exists():
    tilePath.mkdir(parents = True, exist_ok = True)

measurement_directory = Path(SARFish_root_directory, product_type, row["DATA_PARTITION"],  f"{row[f'{product_type}_product_identifier']}.SAFE", "measurement",  )


measurement_directory

# %% [markdown]
# ## Guardado de Tiles
#
# Cada tile se guarda en formato .npy. Esto facilita la carga y manipulación de los datos durante la fase de entrenamiento de modelos de machine learning.

# %%
for index, row in xView3_SLC_GRD_correspondences.iterrows():
    for swath_index in [1, 2, 3]:
        outDir = Path(tilePath, row[f"{product_type}_product_identifier"], f"swath{swath_index}")
        if outDir.exists():
            continue

        measurement_directory = Path(
            SARFish_root_directory, product_type, row["DATA_PARTITION"], 
            f"{row[f'{product_type}_product_identifier']}.SAFE", "measurement", 
        )
        vh_FN = Path(measurement_directory, row[f"SLC_swath_{swath_index}_vh"])
        vv_FN = Path(measurement_directory, row[f"SLC_swath_{swath_index}_vv"])

        # Check if files exist
        if not vh_FN.exists() or not vv_FN.exists():
            print(f"Error: Files do not exist at {vh_FN} and/or {vv_FN}")
            continue

        print(f"tiling {row[f'{product_type}_product_identifier']}, swath {swath_index}, VH at {vh_FN}, VV at {vv_FN}")
        combined = combineVHVV(vh_FN, vv_FN, tileSize, tileOverlap)
        chopAndSaveTiles(combined, outDir, tileSize, tileOverlap)
# Out:
# tiling S1B_IW_SLC__1SDV_20200803T075720_20200803T075748_022756_02B2FF_E5D2, swath 1, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200803T075720_20200803T075748_022756_02B2FF_E5D2.SAFE/measurement/s1b-iw1-slc-vh-20200803t075720-20200803t075748-022756-02b2ff-001_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200803T075720_20200803T075748_022756_02B2FF_E5D2.SAFE/measurement/s1b-iw1-slc-vv-20200803t075720-20200803t075748-022756-02b2ff-004_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200803T075720_20200803T075748_022756_02B2FF_E5D2, swath 2, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200803T075720_20200803T075748_022756_02B2FF_E5D2.SAFE/measurement/s1b-iw2-slc-vh-20200803t075721-20200803t075746-022756-02b2ff-002_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200803T075720_20200803T075748_022756_02B2FF_E5D2.SAFE/measurement/s1b-iw2-slc-vv-20200803t075721-20200803t075746-022756-02b2ff-005_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200803T075720_20200803T075748_022756_02B2FF_E5D2, swath 3, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200803T075720_20200803T075748_022756_02B2FF_E5D2.SAFE/measurement/s1b-iw3-slc-vh-20200803t075722-20200803t075747-022756-02b2ff-003_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200803T075720_20200803T075748_022756_02B2FF_E5D2.SAFE/measurement/s1b-iw3-slc-vv-20200803t075722-20200803t075747-022756-02b2ff-006_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200706T074222_20200706T074242_033331_03DC92_2526, swath 1, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200706T074222_20200706T074242_033331_03DC92_2526.SAFE/measurement/s1a-iw1-slc-vh-20200706t074224-20200706t074240-033331-03dc92-001_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200706T074222_20200706T074242_033331_03DC92_2526.SAFE/measurement/s1a-iw1-slc-vv-20200706t074224-20200706t074240-033331-03dc92-004_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200706T074222_20200706T074242_033331_03DC92_2526, swath 2, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200706T074222_20200706T074242_033331_03DC92_2526.SAFE/measurement/s1a-iw2-slc-vh-20200706t074222-20200706t074241-033331-03dc92-002_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200706T074222_20200706T074242_033331_03DC92_2526.SAFE/measurement/s1a-iw2-slc-vv-20200706t074222-20200706t074241-033331-03dc92-005_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200706T074222_20200706T074242_033331_03DC92_2526, swath 3, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200706T074222_20200706T074242_033331_03DC92_2526.SAFE/measurement/s1a-iw3-slc-vh-20200706t074223-20200706t074242-033331-03dc92-003_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200706T074222_20200706T074242_033331_03DC92_2526.SAFE/measurement/s1a-iw3-slc-vv-20200706t074223-20200706t074242-033331-03dc92-006_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200421T050338_20200421T050406_032221_03BA14_7DD2, swath 1, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200421T050338_20200421T050406_032221_03BA14_7DD2.SAFE/measurement/s1a-iw1-slc-vh-20200421t050339-20200421t050404-032221-03ba14-001_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200421T050338_20200421T050406_032221_03BA14_7DD2.SAFE/measurement/s1a-iw1-slc-vv-20200421t050339-20200421t050404-032221-03ba14-004_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200421T050338_20200421T050406_032221_03BA14_7DD2, swath 2, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200421T050338_20200421T050406_032221_03BA14_7DD2.SAFE/measurement/s1a-iw2-slc-vh-20200421t050340-20200421t050405-032221-03ba14-002_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200421T050338_20200421T050406_032221_03BA14_7DD2.SAFE/measurement/s1a-iw2-slc-vv-20200421t050340-20200421t050405-032221-03ba14-005_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200421T050338_20200421T050406_032221_03BA14_7DD2, swath 3, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200421T050338_20200421T050406_032221_03BA14_7DD2.SAFE/measurement/s1a-iw3-slc-vh-20200421t050338-20200421t050406-032221-03ba14-003_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200421T050338_20200421T050406_032221_03BA14_7DD2.SAFE/measurement/s1a-iw3-slc-vv-20200421t050338-20200421t050406-032221-03ba14-006_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200807T050319_20200807T050346_033796_03EB07_85FB, swath 1, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200807T050319_20200807T050346_033796_03EB07_85FB.SAFE/measurement/s1a-iw1-slc-vh-20200807t050320-20200807t050345-033796-03eb07-001_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200807T050319_20200807T050346_033796_03EB07_85FB.SAFE/measurement/s1a-iw1-slc-vv-20200807t050320-20200807t050345-033796-03eb07-004_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200807T050319_20200807T050346_033796_03EB07_85FB, swath 2, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200807T050319_20200807T050346_033796_03EB07_85FB.SAFE/measurement/s1a-iw2-slc-vh-20200807t050321-20200807t050346-033796-03eb07-002_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200807T050319_20200807T050346_033796_03EB07_85FB.SAFE/measurement/s1a-iw2-slc-vv-20200807t050321-20200807t050346-033796-03eb07-005_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200807T050319_20200807T050346_033796_03EB07_85FB, swath 3, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200807T050319_20200807T050346_033796_03EB07_85FB.SAFE/measurement/s1a-iw3-slc-vh-20200807t050319-20200807t050345-033796-03eb07-003_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200807T050319_20200807T050346_033796_03EB07_85FB.SAFE/measurement/s1a-iw3-slc-vv-20200807t050319-20200807t050345-033796-03eb07-006_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200511T062006_20200511T062033_021530_028E04_7727, swath 1, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200511T062006_20200511T062033_021530_028E04_7727.SAFE/measurement/s1b-iw1-slc-vh-20200511t062007-20200511t062032-021530-028e04-001_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200511T062006_20200511T062033_021530_028E04_7727.SAFE/measurement/s1b-iw1-slc-vv-20200511t062007-20200511t062032-021530-028e04-004_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200511T062006_20200511T062033_021530_028E04_7727, swath 2, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200511T062006_20200511T062033_021530_028E04_7727.SAFE/measurement/s1b-iw2-slc-vh-20200511t062008-20200511t062033-021530-028e04-002_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200511T062006_20200511T062033_021530_028E04_7727.SAFE/measurement/s1b-iw2-slc-vv-20200511t062008-20200511t062033-021530-028e04-005_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200511T062006_20200511T062033_021530_028E04_7727, swath 3, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200511T062006_20200511T062033_021530_028E04_7727.SAFE/measurement/s1b-iw3-slc-vh-20200511t062006-20200511t062031-021530-028e04-003_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200511T062006_20200511T062033_021530_028E04_7727.SAFE/measurement/s1b-iw3-slc-vv-20200511t062006-20200511t062031-021530-028e04-006_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200527T054812_20200527T054838_021763_0294E5_89D9, swath 1, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200527T054812_20200527T054838_021763_0294E5_89D9.SAFE/measurement/s1b-iw1-slc-vh-20200527t054812-20200527t054838-021763-0294e5-001_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200527T054812_20200527T054838_021763_0294E5_89D9.SAFE/measurement/s1b-iw1-slc-vv-20200527t054812-20200527t054838-021763-0294e5-004_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200527T054812_20200527T054838_021763_0294E5_89D9, swath 2, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200527T054812_20200527T054838_021763_0294E5_89D9.SAFE/measurement/s1b-iw2-slc-vh-20200527t054813-20200527t054838-021763-0294e5-002_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200527T054812_20200527T054838_021763_0294E5_89D9.SAFE/measurement/s1b-iw2-slc-vv-20200527t054813-20200527t054838-021763-0294e5-005_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200527T054812_20200527T054838_021763_0294E5_89D9, swath 3, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200527T054812_20200527T054838_021763_0294E5_89D9.SAFE/measurement/s1b-iw3-slc-vh-20200527t054812-20200527t054837-021763-0294e5-003_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200527T054812_20200527T054838_021763_0294E5_89D9.SAFE/measurement/s1b-iw3-slc-vv-20200527t054812-20200527t054837-021763-0294e5-006_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200905T055556_20200905T055623_023236_02C208_B2C6, swath 1, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200905T055556_20200905T055623_023236_02C208_B2C6.SAFE/measurement/s1b-iw1-slc-vh-20200905t055557-20200905t055622-023236-02c208-001_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200905T055556_20200905T055623_023236_02C208_B2C6.SAFE/measurement/s1b-iw1-slc-vv-20200905t055557-20200905t055622-023236-02c208-004_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200905T055556_20200905T055623_023236_02C208_B2C6, swath 2, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200905T055556_20200905T055623_023236_02C208_B2C6.SAFE/measurement/s1b-iw2-slc-vh-20200905t055558-20200905t055623-023236-02c208-002_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200905T055556_20200905T055623_023236_02C208_B2C6.SAFE/measurement/s1b-iw2-slc-vv-20200905t055558-20200905t055623-023236-02c208-005_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200905T055556_20200905T055623_023236_02C208_B2C6, swath 3, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200905T055556_20200905T055623_023236_02C208_B2C6.SAFE/measurement/s1b-iw3-slc-vh-20200905t055556-20200905t055621-023236-02c208-003_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200905T055556_20200905T055623_023236_02C208_B2C6.SAFE/measurement/s1b-iw3-slc-vv-20200905t055556-20200905t055621-023236-02c208-006_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200522T050603_20200522T050631_032673_03C8C7_E420, swath 1, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200522T050603_20200522T050631_032673_03C8C7_E420.SAFE/measurement/s1a-iw1-slc-vh-20200522t050603-20200522t050631-032673-03c8c7-001_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200522T050603_20200522T050631_032673_03C8C7_E420.SAFE/measurement/s1a-iw1-slc-vv-20200522t050603-20200522t050631-032673-03c8c7-004_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200522T050603_20200522T050631_032673_03C8C7_E420, swath 2, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200522T050603_20200522T050631_032673_03C8C7_E420.SAFE/measurement/s1a-iw2-slc-vh-20200522t050604-20200522t050629-032673-03c8c7-002_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200522T050603_20200522T050631_032673_03C8C7_E420.SAFE/measurement/s1a-iw2-slc-vv-20200522t050604-20200522t050629-032673-03c8c7-005_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200522T050603_20200522T050631_032673_03C8C7_E420, swath 3, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200522T050603_20200522T050631_032673_03C8C7_E420.SAFE/measurement/s1a-iw3-slc-vh-20200522t050605-20200522t050630-032673-03c8c7-003_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200522T050603_20200522T050631_032673_03C8C7_E420.SAFE/measurement/s1a-iw3-slc-vv-20200522t050605-20200522t050630-032673-03c8c7-006_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200912T054753_20200912T054820_023338_02C52B_D4CB, swath 1, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200912T054753_20200912T054820_023338_02C52B_D4CB.SAFE/measurement/s1b-iw1-slc-vh-20200912t054754-20200912t054819-023338-02c52b-001_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200912T054753_20200912T054820_023338_02C52B_D4CB.SAFE/measurement/s1b-iw1-slc-vv-20200912t054754-20200912t054819-023338-02c52b-004_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200912T054753_20200912T054820_023338_02C52B_D4CB, swath 2, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200912T054753_20200912T054820_023338_02C52B_D4CB.SAFE/measurement/s1b-iw2-slc-vh-20200912t054755-20200912t054820-023338-02c52b-002_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200912T054753_20200912T054820_023338_02C52B_D4CB.SAFE/measurement/s1b-iw2-slc-vv-20200912t054755-20200912t054820-023338-02c52b-005_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200912T054753_20200912T054820_023338_02C52B_D4CB, swath 3, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200912T054753_20200912T054820_023338_02C52B_D4CB.SAFE/measurement/s1b-iw3-slc-vh-20200912t054753-20200912t054818-023338-02c52b-003_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200912T054753_20200912T054820_023338_02C52B_D4CB.SAFE/measurement/s1b-iw3-slc-vv-20200912t054753-20200912t054818-023338-02c52b-006_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20201018T054753_20201018T054820_023863_02D58D_8CE7, swath 1, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20201018T054753_20201018T054820_023863_02D58D_8CE7.SAFE/measurement/s1b-iw1-slc-vh-20201018t054754-20201018t054819-023863-02d58d-001_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20201018T054753_20201018T054820_023863_02D58D_8CE7.SAFE/measurement/s1b-iw1-slc-vv-20201018t054754-20201018t054819-023863-02d58d-004_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20201018T054753_20201018T054820_023863_02D58D_8CE7, swath 2, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20201018T054753_20201018T054820_023863_02D58D_8CE7.SAFE/measurement/s1b-iw2-slc-vh-20201018t054755-20201018t054820-023863-02d58d-002_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20201018T054753_20201018T054820_023863_02D58D_8CE7.SAFE/measurement/s1b-iw2-slc-vv-20201018t054755-20201018t054820-023863-02d58d-005_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20201018T054753_20201018T054820_023863_02D58D_8CE7, swath 3, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20201018T054753_20201018T054820_023863_02D58D_8CE7.SAFE/measurement/s1b-iw3-slc-vh-20201018t054753-20201018t054818-023863-02d58d-003_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20201018T054753_20201018T054820_023863_02D58D_8CE7.SAFE/measurement/s1b-iw3-slc-vv-20201018t054753-20201018t054818-023863-02d58d-006_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200807T054816_20200807T054843_022813_02B4C5_5575, swath 1, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200807T054816_20200807T054843_022813_02B4C5_5575.SAFE/measurement/s1b-iw1-slc-vh-20200807t054817-20200807t054842-022813-02b4c5-001_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200807T054816_20200807T054843_022813_02B4C5_5575.SAFE/measurement/s1b-iw1-slc-vv-20200807t054817-20200807t054842-022813-02b4c5-004_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200807T054816_20200807T054843_022813_02B4C5_5575, swath 2, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200807T054816_20200807T054843_022813_02B4C5_5575.SAFE/measurement/s1b-iw2-slc-vh-20200807t054818-20200807t054843-022813-02b4c5-002_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200807T054816_20200807T054843_022813_02B4C5_5575.SAFE/measurement/s1b-iw2-slc-vv-20200807t054818-20200807t054843-022813-02b4c5-005_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200807T054816_20200807T054843_022813_02B4C5_5575, swath 3, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200807T054816_20200807T054843_022813_02B4C5_5575.SAFE/measurement/s1b-iw3-slc-vh-20200807t054816-20200807t054841-022813-02b4c5-003_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200807T054816_20200807T054843_022813_02B4C5_5575.SAFE/measurement/s1b-iw3-slc-vv-20200807t054816-20200807t054841-022813-02b4c5-006_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200807T054751_20200807T054818_022813_02B4C5_01F5, swath 1, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200807T054751_20200807T054818_022813_02B4C5_01F5.SAFE/measurement/s1b-iw1-slc-vh-20200807t054752-20200807t054817-022813-02b4c5-001_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200807T054751_20200807T054818_022813_02B4C5_01F5.SAFE/measurement/s1b-iw1-slc-vv-20200807t054752-20200807t054817-022813-02b4c5-004_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200807T054751_20200807T054818_022813_02B4C5_01F5, swath 2, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200807T054751_20200807T054818_022813_02B4C5_01F5.SAFE/measurement/s1b-iw2-slc-vh-20200807t054753-20200807t054818-022813-02b4c5-002_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200807T054751_20200807T054818_022813_02B4C5_01F5.SAFE/measurement/s1b-iw2-slc-vv-20200807t054753-20200807t054818-022813-02b4c5-005_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200807T054751_20200807T054818_022813_02B4C5_01F5, swath 3, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200807T054751_20200807T054818_022813_02B4C5_01F5.SAFE/measurement/s1b-iw3-slc-vh-20200807t054751-20200807t054816-022813-02b4c5-003_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200807T054751_20200807T054818_022813_02B4C5_01F5.SAFE/measurement/s1b-iw3-slc-vv-20200807t054751-20200807t054816-022813-02b4c5-006_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200831T054752_20200831T054819_023163_02BFB2_13D6, swath 1, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200831T054752_20200831T054819_023163_02BFB2_13D6.SAFE/measurement/s1b-iw1-slc-vh-20200831t054753-20200831t054818-023163-02bfb2-001_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200831T054752_20200831T054819_023163_02BFB2_13D6.SAFE/measurement/s1b-iw1-slc-vv-20200831t054753-20200831t054818-023163-02bfb2-004_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200831T054752_20200831T054819_023163_02BFB2_13D6, swath 2, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200831T054752_20200831T054819_023163_02BFB2_13D6.SAFE/measurement/s1b-iw2-slc-vh-20200831t054754-20200831t054819-023163-02bfb2-002_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200831T054752_20200831T054819_023163_02BFB2_13D6.SAFE/measurement/s1b-iw2-slc-vv-20200831t054754-20200831t054819-023163-02bfb2-005_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200831T054752_20200831T054819_023163_02BFB2_13D6, swath 3, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200831T054752_20200831T054819_023163_02BFB2_13D6.SAFE/measurement/s1b-iw3-slc-vh-20200831t054752-20200831t054817-023163-02bfb2-003_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200831T054752_20200831T054819_023163_02BFB2_13D6.SAFE/measurement/s1b-iw3-slc-vv-20200831t054752-20200831t054817-023163-02bfb2-006_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200922T060415_20200922T060442_023484_02C9BF_EA4B, swath 1, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200922T060415_20200922T060442_023484_02C9BF_EA4B.SAFE/measurement/s1b-iw1-slc-vh-20200922t060416-20200922t060441-023484-02c9bf-001_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200922T060415_20200922T060442_023484_02C9BF_EA4B.SAFE/measurement/s1b-iw1-slc-vv-20200922t060416-20200922t060441-023484-02c9bf-004_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200922T060415_20200922T060442_023484_02C9BF_EA4B, swath 2, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200922T060415_20200922T060442_023484_02C9BF_EA4B.SAFE/measurement/s1b-iw2-slc-vh-20200922t060416-20200922t060442-023484-02c9bf-002_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200922T060415_20200922T060442_023484_02C9BF_EA4B.SAFE/measurement/s1b-iw2-slc-vv-20200922t060416-20200922t060442-023484-02c9bf-005_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200922T060415_20200922T060442_023484_02C9BF_EA4B, swath 3, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200922T060415_20200922T060442_023484_02C9BF_EA4B.SAFE/measurement/s1b-iw3-slc-vh-20200922t060415-20200922t060440-023484-02c9bf-003_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200922T060415_20200922T060442_023484_02C9BF_EA4B.SAFE/measurement/s1b-iw3-slc-vv-20200922t060415-20200922t060440-023484-02c9bf-006_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200403T054834_20200403T054901_031959_03B0CA_FD46, swath 1, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200403T054834_20200403T054901_031959_03B0CA_FD46.SAFE/measurement/s1a-iw1-slc-vh-20200403t054835-20200403t054900-031959-03b0ca-001_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200403T054834_20200403T054901_031959_03B0CA_FD46.SAFE/measurement/s1a-iw1-slc-vv-20200403t054835-20200403t054900-031959-03b0ca-004_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200403T054834_20200403T054901_031959_03B0CA_FD46, swath 2, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200403T054834_20200403T054901_031959_03B0CA_FD46.SAFE/measurement/s1a-iw2-slc-vh-20200403t054836-20200403t054901-031959-03b0ca-002_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200403T054834_20200403T054901_031959_03B0CA_FD46.SAFE/measurement/s1a-iw2-slc-vv-20200403t054836-20200403t054901-031959-03b0ca-005_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200403T054834_20200403T054901_031959_03B0CA_FD46, swath 3, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200403T054834_20200403T054901_031959_03B0CA_FD46.SAFE/measurement/s1a-iw3-slc-vh-20200403t054834-20200403t054859-031959-03b0ca-003_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200403T054834_20200403T054901_031959_03B0CA_FD46.SAFE/measurement/s1a-iw3-slc-vv-20200403t054834-20200403t054859-031959-03b0ca-006_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200719T055553_20200719T055620_022536_02AC5E_ABAE, swath 1, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200719T055553_20200719T055620_022536_02AC5E_ABAE.SAFE/measurement/s1b-iw1-slc-vh-20200719t055554-20200719t055619-022536-02ac5e-001_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200719T055553_20200719T055620_022536_02AC5E_ABAE.SAFE/measurement/s1b-iw1-slc-vv-20200719t055554-20200719t055619-022536-02ac5e-004_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200719T055553_20200719T055620_022536_02AC5E_ABAE, swath 2, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200719T055553_20200719T055620_022536_02AC5E_ABAE.SAFE/measurement/s1b-iw2-slc-vh-20200719t055555-20200719t055620-022536-02ac5e-002_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200719T055553_20200719T055620_022536_02AC5E_ABAE.SAFE/measurement/s1b-iw2-slc-vv-20200719t055555-20200719t055620-022536-02ac5e-005_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200719T055553_20200719T055620_022536_02AC5E_ABAE, swath 3, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200719T055553_20200719T055620_022536_02AC5E_ABAE.SAFE/measurement/s1b-iw3-slc-vh-20200719t055553-20200719t055618-022536-02ac5e-003_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200719T055553_20200719T055620_022536_02AC5E_ABAE.SAFE/measurement/s1b-iw3-slc-vv-20200719t055553-20200719t055618-022536-02ac5e-006_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200221T054744_20200221T054811_020363_026919_0E4E, swath 1, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200221T054744_20200221T054811_020363_026919_0E4E.SAFE/measurement/s1b-iw1-slc-vh-20200221t054745-20200221t054810-020363-026919-001_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200221T054744_20200221T054811_020363_026919_0E4E.SAFE/measurement/s1b-iw1-slc-vv-20200221t054745-20200221t054810-020363-026919-004_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200221T054744_20200221T054811_020363_026919_0E4E, swath 2, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200221T054744_20200221T054811_020363_026919_0E4E.SAFE/measurement/s1b-iw2-slc-vh-20200221t054745-20200221t054811-020363-026919-002_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200221T054744_20200221T054811_020363_026919_0E4E.SAFE/measurement/s1b-iw2-slc-vv-20200221t054745-20200221t054811-020363-026919-005_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200221T054744_20200221T054811_020363_026919_0E4E, swath 3, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200221T054744_20200221T054811_020363_026919_0E4E.SAFE/measurement/s1b-iw3-slc-vh-20200221t054744-20200221t054809-020363-026919-003_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200221T054744_20200221T054811_020363_026919_0E4E.SAFE/measurement/s1b-iw3-slc-vv-20200221t054744-20200221t054809-020363-026919-006_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200427T054835_20200427T054902_032309_03BD1A_0BE5, swath 1, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200427T054835_20200427T054902_032309_03BD1A_0BE5.SAFE/measurement/s1a-iw1-slc-vh-20200427t054836-20200427t054901-032309-03bd1a-001_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200427T054835_20200427T054902_032309_03BD1A_0BE5.SAFE/measurement/s1a-iw1-slc-vv-20200427t054836-20200427t054901-032309-03bd1a-004_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200427T054835_20200427T054902_032309_03BD1A_0BE5, swath 2, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200427T054835_20200427T054902_032309_03BD1A_0BE5.SAFE/measurement/s1a-iw2-slc-vh-20200427t054837-20200427t054902-032309-03bd1a-002_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200427T054835_20200427T054902_032309_03BD1A_0BE5.SAFE/measurement/s1a-iw2-slc-vv-20200427t054837-20200427t054902-032309-03bd1a-005_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200427T054835_20200427T054902_032309_03BD1A_0BE5, swath 3, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200427T054835_20200427T054902_032309_03BD1A_0BE5.SAFE/measurement/s1a-iw3-slc-vh-20200427t054835-20200427t054900-032309-03bd1a-003_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200427T054835_20200427T054902_032309_03BD1A_0BE5.SAFE/measurement/s1a-iw3-slc-vv-20200427t054835-20200427t054900-032309-03bd1a-006_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200929T170920_20200929T170947_023593_02CD35_0989, swath 1, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200929T170920_20200929T170947_023593_02CD35_0989.SAFE/measurement/s1b-iw1-slc-vh-20200929t170921-20200929t170946-023593-02cd35-001_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200929T170920_20200929T170947_023593_02CD35_0989.SAFE/measurement/s1b-iw1-slc-vv-20200929t170921-20200929t170946-023593-02cd35-004_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200929T170920_20200929T170947_023593_02CD35_0989, swath 2, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200929T170920_20200929T170947_023593_02CD35_0989.SAFE/measurement/s1b-iw2-slc-vh-20200929t170922-20200929t170947-023593-02cd35-002_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200929T170920_20200929T170947_023593_02CD35_0989.SAFE/measurement/s1b-iw2-slc-vv-20200929t170922-20200929t170947-023593-02cd35-005_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200929T170920_20200929T170947_023593_02CD35_0989, swath 3, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200929T170920_20200929T170947_023593_02CD35_0989.SAFE/measurement/s1b-iw3-slc-vh-20200929t170920-20200929t170945-023593-02cd35-003_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200929T170920_20200929T170947_023593_02CD35_0989.SAFE/measurement/s1b-iw3-slc-vv-20200929t170920-20200929t170945-023593-02cd35-006_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200402T170911_20200402T170938_020968_027C5A_2EF6, swath 1, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200402T170911_20200402T170938_020968_027C5A_2EF6.SAFE/measurement/s1b-iw1-slc-vh-20200402t170912-20200402t170937-020968-027c5a-001_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200402T170911_20200402T170938_020968_027C5A_2EF6.SAFE/measurement/s1b-iw1-slc-vv-20200402t170912-20200402t170937-020968-027c5a-004_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200402T170911_20200402T170938_020968_027C5A_2EF6, swath 2, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200402T170911_20200402T170938_020968_027C5A_2EF6.SAFE/measurement/s1b-iw2-slc-vh-20200402t170913-20200402t170938-020968-027c5a-002_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200402T170911_20200402T170938_020968_027C5A_2EF6.SAFE/measurement/s1b-iw2-slc-vv-20200402t170913-20200402t170938-020968-027c5a-005_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200402T170911_20200402T170938_020968_027C5A_2EF6, swath 3, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200402T170911_20200402T170938_020968_027C5A_2EF6.SAFE/measurement/s1b-iw3-slc-vh-20200402t170911-20200402t170936-020968-027c5a-003_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200402T170911_20200402T170938_020968_027C5A_2EF6.SAFE/measurement/s1b-iw3-slc-vv-20200402t170911-20200402t170936-020968-027c5a-006_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200726T165739_20200726T165806_022645_02AFAD_6A9B, swath 1, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200726T165739_20200726T165806_022645_02AFAD_6A9B.SAFE/measurement/s1b-iw1-slc-vh-20200726t165739-20200726t165804-022645-02afad-001_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200726T165739_20200726T165806_022645_02AFAD_6A9B.SAFE/measurement/s1b-iw1-slc-vv-20200726t165739-20200726t165804-022645-02afad-004_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200726T165739_20200726T165806_022645_02AFAD_6A9B, swath 2, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200726T165739_20200726T165806_022645_02AFAD_6A9B.SAFE/measurement/s1b-iw2-slc-vh-20200726t165740-20200726t165805-022645-02afad-002_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200726T165739_20200726T165806_022645_02AFAD_6A9B.SAFE/measurement/s1b-iw2-slc-vv-20200726t165740-20200726t165805-022645-02afad-005_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200726T165739_20200726T165806_022645_02AFAD_6A9B, swath 3, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200726T165739_20200726T165806_022645_02AFAD_6A9B.SAFE/measurement/s1b-iw3-slc-vh-20200726t165741-20200726t165806-022645-02afad-003_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200726T165739_20200726T165806_022645_02AFAD_6A9B.SAFE/measurement/s1b-iw3-slc-vv-20200726t165741-20200726t165806-022645-02afad-006_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200427T054900_20200427T054928_032309_03BD1A_6DE0, swath 1, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200427T054900_20200427T054928_032309_03BD1A_6DE0.SAFE/measurement/s1a-iw1-slc-vh-20200427t054901-20200427t054926-032309-03bd1a-001_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200427T054900_20200427T054928_032309_03BD1A_6DE0.SAFE/measurement/s1a-iw1-slc-vv-20200427t054901-20200427t054926-032309-03bd1a-004_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200427T054900_20200427T054928_032309_03BD1A_6DE0, swath 2, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200427T054900_20200427T054928_032309_03BD1A_6DE0.SAFE/measurement/s1a-iw2-slc-vh-20200427t054902-20200427t054927-032309-03bd1a-002_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200427T054900_20200427T054928_032309_03BD1A_6DE0.SAFE/measurement/s1a-iw2-slc-vv-20200427t054902-20200427t054927-032309-03bd1a-005_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200427T054900_20200427T054928_032309_03BD1A_6DE0, swath 3, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200427T054900_20200427T054928_032309_03BD1A_6DE0.SAFE/measurement/s1a-iw3-slc-vh-20200427t054900-20200427t054928-032309-03bd1a-003_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200427T054900_20200427T054928_032309_03BD1A_6DE0.SAFE/measurement/s1a-iw3-slc-vv-20200427t054900-20200427t054928-032309-03bd1a-006_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200520T051115_20200520T051142_032644_03C7E8_E2BE, swath 1, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200520T051115_20200520T051142_032644_03C7E8_E2BE.SAFE/measurement/s1a-iw1-slc-vh-20200520t051117-20200520t051142-032644-03c7e8-001_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200520T051115_20200520T051142_032644_03C7E8_E2BE.SAFE/measurement/s1a-iw1-slc-vv-20200520t051117-20200520t051142-032644-03c7e8-004_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200520T051115_20200520T051142_032644_03C7E8_E2BE, swath 2, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200520T051115_20200520T051142_032644_03C7E8_E2BE.SAFE/measurement/s1a-iw2-slc-vh-20200520t051115-20200520t051141-032644-03c7e8-002_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200520T051115_20200520T051142_032644_03C7E8_E2BE.SAFE/measurement/s1a-iw2-slc-vv-20200520t051115-20200520t051141-032644-03c7e8-005_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200520T051115_20200520T051142_032644_03C7E8_E2BE, swath 3, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200520T051115_20200520T051142_032644_03C7E8_E2BE.SAFE/measurement/s1a-iw3-slc-vh-20200520t051116-20200520t051142-032644-03c7e8-003_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200520T051115_20200520T051142_032644_03C7E8_E2BE.SAFE/measurement/s1a-iw3-slc-vv-20200520t051116-20200520t051142-032644-03c7e8-006_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200928T171759_20200928T171831_034562_0405EA_2228, swath 1, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200928T171759_20200928T171831_034562_0405EA_2228.SAFE/measurement/s1a-iw1-slc-vh-20200928t171759-20200928t171830-034562-0405ea-001_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200928T171759_20200928T171831_034562_0405EA_2228.SAFE/measurement/s1a-iw1-slc-vv-20200928t171759-20200928t171830-034562-0405ea-004_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200928T171759_20200928T171831_034562_0405EA_2228, swath 2, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200928T171759_20200928T171831_034562_0405EA_2228.SAFE/measurement/s1a-iw2-slc-vh-20200928t171800-20200928t171830-034562-0405ea-002_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200928T171759_20200928T171831_034562_0405EA_2228.SAFE/measurement/s1a-iw2-slc-vv-20200928t171800-20200928t171830-034562-0405ea-005_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200928T171759_20200928T171831_034562_0405EA_2228, swath 3, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200928T171759_20200928T171831_034562_0405EA_2228.SAFE/measurement/s1a-iw3-slc-vh-20200928t171801-20200928t171831-034562-0405ea-003_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200928T171759_20200928T171831_034562_0405EA_2228.SAFE/measurement/s1a-iw3-slc-vv-20200928t171801-20200928t171831-034562-0405ea-006_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200910T053004_20200910T053034_034292_03FC65_1F7A, swath 1, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200910T053004_20200910T053034_034292_03FC65_1F7A.SAFE/measurement/s1a-iw1-slc-vh-20200910t053004-20200910t053032-034292-03fc65-001_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200910T053004_20200910T053034_034292_03FC65_1F7A.SAFE/measurement/s1a-iw1-slc-vv-20200910t053004-20200910t053032-034292-03fc65-004_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200910T053004_20200910T053034_034292_03FC65_1F7A, swath 2, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200910T053004_20200910T053034_034292_03FC65_1F7A.SAFE/measurement/s1a-iw2-slc-vh-20200910t053005-20200910t053033-034292-03fc65-002_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200910T053004_20200910T053034_034292_03FC65_1F7A.SAFE/measurement/s1a-iw2-slc-vv-20200910t053005-20200910t053033-034292-03fc65-005_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200910T053004_20200910T053034_034292_03FC65_1F7A, swath 3, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200910T053004_20200910T053034_034292_03FC65_1F7A.SAFE/measurement/s1a-iw3-slc-vh-20200910t053006-20200910t053034-034292-03fc65-003_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200910T053004_20200910T053034_034292_03FC65_1F7A.SAFE/measurement/s1a-iw3-slc-vv-20200910t053006-20200910t053034-034292-03fc65-006_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200126T052956_20200126T053026_030967_038E50_4681, swath 1, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200126T052956_20200126T053026_030967_038E50_4681.SAFE/measurement/s1a-iw1-slc-vh-20200126t052956-20200126t053024-030967-038e50-001_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200126T052956_20200126T053026_030967_038E50_4681.SAFE/measurement/s1a-iw1-slc-vv-20200126t052956-20200126t053024-030967-038e50-004_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200126T052956_20200126T053026_030967_038E50_4681, swath 2, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200126T052956_20200126T053026_030967_038E50_4681.SAFE/measurement/s1a-iw2-slc-vh-20200126t052957-20200126t053025-030967-038e50-002_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200126T052956_20200126T053026_030967_038E50_4681.SAFE/measurement/s1a-iw2-slc-vv-20200126t052957-20200126t053025-030967-038e50-005_SARFish.tiff
# tiling S1A_IW_SLC__1SDV_20200126T052956_20200126T053026_030967_038E50_4681, swath 3, VH at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200126T052956_20200126T053026_030967_038E50_4681.SAFE/measurement/s1a-iw3-slc-vh-20200126t052958-20200126t053026-030967-038e50-003_SARFish.tiff, VV at ../../data/SLC/validation/S1A_IW_SLC__1SDV_20200126T052956_20200126T053026_030967_038E50_4681.SAFE/measurement/s1a-iw3-slc-vv-20200126t052958-20200126t053026-030967-038e50-006_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200826T054007_20200826T054034_023090_02BD74_03D2, swath 1, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200826T054007_20200826T054034_023090_02BD74_03D2.SAFE/measurement/s1b-iw1-slc-vh-20200826t054008-20200826t054033-023090-02bd74-001_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200826T054007_20200826T054034_023090_02BD74_03D2.SAFE/measurement/s1b-iw1-slc-vv-20200826t054008-20200826t054033-023090-02bd74-004_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200826T054007_20200826T054034_023090_02BD74_03D2, swath 2, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200826T054007_20200826T054034_023090_02BD74_03D2.SAFE/measurement/s1b-iw2-slc-vh-20200826t054009-20200826t054034-023090-02bd74-002_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200826T054007_20200826T054034_023090_02BD74_03D2.SAFE/measurement/s1b-iw2-slc-vv-20200826t054009-20200826t054034-023090-02bd74-005_SARFish.tiff
# tiling S1B_IW_SLC__1SDV_20200826T054007_20200826T054034_023090_02BD74_03D2, swath 3, VH at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200826T054007_20200826T054034_023090_02BD74_03D2.SAFE/measurement/s1b-iw3-slc-vh-20200826t054007-20200826t054032-023090-02bd74-003_SARFish.tiff, VV at ../../data/SLC/validation/S1B_IW_SLC__1SDV_20200826T054007_20200826T054034_023090_02BD74_03D2.SAFE/measurement/s1b-iw3-slc-vv-20200826t054007-20200826t054032-023090-02bd74-006_SARFish.tiff
